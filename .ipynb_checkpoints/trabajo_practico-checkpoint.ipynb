# %%
# %load_ext autoreload
# %autoreload 2

# %%
from camera import CameraReader, display_frame
from IPython.display import display
import ipywidgets as widgets
import numpy as np
import sys
import scipy.signal
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import animation, patches
from scipy import fftpack
from scipy.signal import fftconvolve, convolve2d

# %%
cam = CameraReader()
vid_height, vid_width = cam.get_resolution()
print("Resolución del video: {0}x{1}p".format(vid_width, vid_height))
print("Cuadros por segundo: {0}".format(cam.get_fps()))

out = widgets.Image(layout=widgets.Layout(width=str(vid_width), 
                                            height=str(vid_height)))
display(out)
#Mostrar en cuadros
fig, ax = plt.subplots(1, 2, figsize=(16, 9), tight_layout=True)
figb, bx = plt.subplots(1, 2, figsize=(16, 9), tight_layout=True)

#Ajuste del filtro
fx, fy = fftpack.fftfreq(n=1000, d=1), fftpack.fftfreq(n=600, d=1)
Fx, Fy = np.meshgrid(fx, fy)
inv_psf =  np.exp(-2*np.pi**2*(Fx**2 + Fy**2)*2**2)
count = 0;
#Ajuste convolucion
x = np.linspace(-5, 5, num=11)
X, Y = np.meshgrid(x, x)
sigma = 2
psf = np.exp(-0.5*(X)**2/sigma**2 - 0.5*Y**2/sigma**2)/(2.0*np.pi*sigma**2)

#hacer mascara
sigma=200
cy, cx = vid_height/2, vid_width/2
x = np.arange(0, vid_width); y = np.arange(0, vid_height);
X, Y = np.meshgrid(x, y)
mask = 1e-8 + np.exp(-(((X-cx)/sigma)**2 + ((Y-cy)/sigma)**2))

#play = widgets.Play


for frame in cam:
    #print(frame[0])
    # Implemente una función que limpie los frames
    #frame_limpio = np.ndarray(frame[0])
    frame = fftconvolve(frame, psf, mode='same') \
    + 20*np.random.randn(frame.shape[0], frame.shape[1])
    frame_sp = (frame.astype('float32'))
    frame_limpio = frame_sp * mask
    #print(sys.getsizeof(frame_limpio))  #getsizeof retorna el tamaño en Bytes
    
    # Implemente una función que comprima los frames
    # frame_comprimido = comprimir(frame)
    # print(sys.getsizeof(frame_comprimido))
    
    # Implemente una función que descomprima los frames
    # frame = descomprimir(frame_compromido)
    # print(cam.error(frame))  # Error de compresión
    count +=1;
    #print(frame)
    #ax[0].imshow(frame); ax[0].set_title("Imagen")
    
    ax[0].imshow(frame);ax[0].set_title("Imagen")
    ax[1].imshow(frame_sp);ax[1].set_title("Espectro")
    
    bx[0].imshow(frame_limpio);bx[0].set_title("Espectro con filtro")
    bx[1].imshow(np.real(frame_limpio));bx[1].set_title("Recuperado")
    
    #display_frame(out, frame)
    #display_frame(out,frame_limpio)
    
    if(count==1):
        break;
    
        
count
# Out:
# Iniciando lector de camara
# OpenCV version: major: 4, minor: 1, subminor: 0
# Resolución del video: 848x480p
# Cuadros por segundo: 29.97002997002997
# Image(value=b'', layout="Layout(height='480', width='848')")
# 1

# %%
#huffman
import scipy
from scipy import fftpack
fftpack.fftshift(np.log(1+np.abs(fftpack.fft2(frame.astype('float32')))))
# Out:
# array([[17.85823 , 17.863626, 17.84514 , ..., 17.843124, 17.84514 ,
#         17.863626],
#        [17.825384, 17.820082, 17.806908, ..., 17.819345, 17.827467,
#         17.837687],
#        [17.79198 , 17.77191 , 17.746315, ..., 17.797338, 17.785637,
#         17.791016],
#        ...,
#        [17.732935, 17.749449, 17.74775 , ..., 17.669998, 17.69195 ,
#         17.7145  ],
#        [17.79198 , 17.791016, 17.785637, ..., 17.744585, 17.746315,
#         17.77191 ],
#        [17.825384, 17.837687, 17.827467, ..., 17.818636, 17.806908,
#         17.820082]], dtype=float32)
